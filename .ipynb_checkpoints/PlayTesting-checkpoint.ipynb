# %%
# %run "BlackjackSetup.ipynb"

# %%
readoutput(t.step((1,0)))
# Out:
# Bankroll is: 90
# Current bet is: 0
# Player has: [np.float64(0.0)]
# Dealer has: [np.float64(0.0)]
# Previous cards: [ 5 13  1  3 12 12]
# Count is -2
# Continue

# %%
t = BlackjackTable()
t.reset()
terminated = False
while not terminated:
    action = np.random
    output =
