# %%
# %run "BlackjackSetup.ipynb"
import numpy as np

# %%
t = BlackjackTable()
t.reset()
terminated = False
while not terminated:
    action = (np.random.choice([0,1]), np.random.choice([0,1]))
    output = t.step(action)
    terminated = output[2]
    readoutput(output)
# Out:
# Bankroll is: 100
# Current bet is: 0
# Player has: [np.float64(0.0)]
# Dealer has: [np.float64(0.0)]
# Previous cards: []
# Count is 0
# Continue
# Bankroll is: 100
# Current bet is: 0
# Player has: [np.float64(0.0)]
# Dealer has: [np.float64(0.0)]
# Previous cards: []
# Count is 0
# Continue
# Bankroll is: 100
# Current bet is: 0
# Player has: [np.int64(7), np.int64(17)]
# Dealer has: [np.int64(7)]
# Previous cards: []
# Count is 0
# Continue
# Bankroll is: 100
# Current bet is: 0
# Player has: [np.int64(7), np.int64(17)]
# Dealer has: [np.int64(7)]
# Previous cards: []
# Count is 0
# Continue
# Bankroll is: 100
# Current bet is: 0
# Player has: [np.int64(7), np.int64(17)]
# Dealer has: [np.int64(7)]
# Previous cards: []
# Count is 0
# Continue
# Bankroll is: 100
# Current bet is: 0
# Player has: [np.int64(7), np.int64(17)]
# Dealer has: [np.int64(7)]
# Previous cards: []
# Count is 0
# Continue
# Bankroll is: 100.0
# Current bet is: 0
# Player has: [np.float64(0.0)]
# ...
